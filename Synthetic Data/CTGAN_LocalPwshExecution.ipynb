# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from pandas.io import json
from tensorflow import keras
from tensorflow.keras import layers
from sklearn import preprocessing

datasetJSONPath = os.getcwd() + "\\datasets\\empire_launcher_vbs_2020-09-04160940.json"
df = json.read_json(path_or_buf=datasetJSONPath, lines=True)

df.shape
# Out:
# C:\Users\ly\AppData\Roaming\Python\Python37\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\ly\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\ly\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   stacklevel=1)
# (2067, 162)

# %%
# functions definition

from collections import Counter
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt

# Convert integers to strings
def int_to_str(df):
    for column in df.columns:
        # if dtype is int, convert to string , e.g. EventID
        if isinstance(df[column][0], (int, np.int32, np.int64)):
            df[column] = list(map(str, df[column]))
            
    return df
    
# Count NaN in each column in the dataframe
def count_nan(df):
    for column in df.columns:
        num = df[column].isna().sum()
        print(column, str(num))
    return 0

# make a label list of all 0, except the detected threat are 1
def labelList(num, threatIndices):
    y = [0 for x in range(num)]
    for i in threatIndices:
        y[i] =  1
    return y

# Count the items in data frame
def count_items(df):
    for column in df.columns:
        item = df[column]
        print(column, ": ", sorted(Counter(item).items()))
        
    return 0

# replicate specified data to the end of the dataset
def pd_replicate(X, y, rep_list, times=1):
    for index in rep_list:
        for i in range(times):
            
            X = pd.concat([X, pd.DataFrame(X.iloc[index]).T], axis=0, ignore_index=True)

            y.append(1)
    
    return (X, y)
    
# convert object items in the list into strings
def preprocess(df):
    
    # replace NAN with 0
    df = df.replace(np.nan, 0, regex=True)
    
    for column in df.columns:            
        df[column] = list(map(str, df[column]))            
    return df

# fit the dataframe and record the label encoders for each column
def labelEncoder_get(df):
    le_list = []
    for column in df.columns:
        le = preprocessing.LabelEncoder()
        le.fit(df[column])
        df[column] = le.transform(df[column])
        le_list.append(le)
    return (df, le_list)

# input the list of label encoders and transform the dataframe
def labelEncoder_trans(df, le_list):
    for i, column in enumerate(df.columns):
        le = le_list[i]
        df[column] = list(map(str, df[column]))
        df[column] = le.transform(df[column])
    return df


# draw confusin matrix and print the classification report
def draw_confusionMatrix(y_test, y_predict):
    confusion_matrix = metrics.confusion_matrix(y_test, y_predict)
    matrix_df = pd.DataFrame(confusion_matrix)
    ax = plt.axes()
    sns.set(font_scale=1.3)
    plt.figure(figsize=(10, 7))
    sns.heatmap(matrix_df, annot=True, fmt="g", ax=ax, cmap="magma")
    ax.set_title('Confusion Matrix - Decision Tree')
    ax.set_xlabel("Predicted Label", fontsize=15)
    ax.set_ylabel("Actual Label", fontsize=15)
    plt.show()
    print(metrics.classification_report(y_test, y_predict))
    

# Randomly pick data from results and combine them
def random_generator(data_list, pick_nums):
    
    generated_data = pd.DataFrame()
    
    for i, data in enumerate(data_list):
        num = pick_nums[i]
        data_selected = data.sample(num)
        generated_data = pd.concat([generated_data, data_selected], axis=0, ignore_index=True)
    
    return generated_data
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
features = ["Channel", "EventID", "NewProcessName", "ParentProcessName", "Image", "ImageLoaded", "Description", "PipeName"]
df = df[features]

# change integers to strings to get a better performance in generating new data
df = int_to_str(df)
df.shape
# Out:
# (2067, 8)

# %% [markdown]
# ## Replicate positive data
#
# There are more negative data than positive data, and results from some analytics (e.g. analytics with merging) are less possible to be generated. So we replicate specific positive data to make CTGAN bias to them.

# %% [markdown]
# ## Use CTGAN to generate new data

# %%
from sdv.tabular import CTGAN

# model = CTGAN(cuda=True)
# model.fit(df)
# save and reuse the model
# model.save('LocalPwshExecution.pkl')

model = CTGAN.load(r'models\\LocalPwshExecution.pkl')

# %%
new_data = model.sample(num_rows=1000000)
new_data.head()
# Out:
#                                 Channel EventID NewProcessName  \
# 0  Microsoft-Windows-Sysmon/Operational    5156            NaN
# 1  Microsoft-Windows-Sysmon/Operational       7            NaN
# 2  Microsoft-Windows-Sysmon/Operational       7            NaN
# 3  Microsoft-Windows-Sysmon/Operational      13            NaN
# 4  Microsoft-Windows-Sysmon/Operational      12            NaN
#
#                  ParentProcessName  \
# 0                              NaN
# 1  C:\Windows\System32\wscript.exe
# 2  C:\Windows\System32\wscript.exe
# 3                              NaN
# 4                              NaN
#
#                                                Image ImageLoaded  \
# 0                                                NaN         NaN
# 1  C:\Windows\System32\WindowsPowerShell\v1.0\pow...         NaN
# 2                    C:\Windows\System32\wscript.exe         NaN
# 3                                                NaN         NaN
# 4                   C:\windows\system32\services.exe         NaN
#
#                                Description  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4  Microsoft .NET Runtime Execution Engine
#
#                                             PipeName
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  \PSHost.132437237957601629.2316.DefaultAppDoma...

# %%
# # for debugging only
# count_items(preprocess_labelEncoder(df))
# count_items(preprocess_labelEncoder(new_data))

# %% [markdown]
# ## Use hunter program on new data

# %%
# Analytic I
I = (
new_data[features]

[((new_data['Channel'] == 'Windows PowerShell') | (new_data['Channel'] == 'Microsoft-Windows-PowerShell/Operational'))
    & (
      (new_data['EventID'] == '400')
      | (new_data['EventID'] == '4103')
    )
]
)
I
# Out:
#                                          Channel EventID  \
# 93      Microsoft-Windows-PowerShell/Operational    4103
# 399                           Windows PowerShell    4103
# 520                           Windows PowerShell    4103
# 834     Microsoft-Windows-PowerShell/Operational    4103
# 851     Microsoft-Windows-PowerShell/Operational    4103
# ...                                          ...     ...
# 997643                        Windows PowerShell    4103
# 997970  Microsoft-Windows-PowerShell/Operational    4103
# 999441  Microsoft-Windows-PowerShell/Operational    4103
# 999629  Microsoft-Windows-PowerShell/Operational    4103
# 999785                        Windows PowerShell    4103
#
#                                            NewProcessName ParentProcessName  \
# 93                                                    NaN               NaN
# 399                        C:\Windows\System32\whoami.exe               NaN
# 520                                                   NaN               NaN
# 834                                                   NaN               NaN
# 851     C:\Windows\System32\WindowsPowerShell\v1.0\pow...               NaN
# ...                                                   ...               ...
# 997643  C:\Windows\System32\WindowsPowerShell\v1.0\pow...               NaN
# 997970  C:\Windows\System32\WindowsPowerShell\v1.0\pow...               NaN
# 999441                                                NaN               NaN
# 999629                    C:\Windows\System32\wscript.exe               NaN
# 999785                                                NaN               NaN
#
#                                                     Image  \
# 93                                                    NaN
# 399                                                   NaN
# 520                                                   NaN
# 834                 C:\Windows\System32\wbem\WmiPrvSE.exe
# 851     C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# ...                                                   ...
# 997643                                                NaN
# 997970                                                NaN
# 999441                                                NaN
# 999629                                                NaN
# 999785                    C:\Windows\System32\wscript.exe
#
#                                               ImageLoaded  \
# 93                                                    NaN
# 399                                                   NaN
# 520                                                   NaN
# 834                                                   NaN
# 851                                                   NaN
# ...                                                   ...
# 997643                                                NaN
# 997970                                                NaN
# 999441  C:\Windows\assembly\NativeImages_v4.0.30319_64...
# 999629                                                NaN
# 999785  C:\Windows\assembly\NativeImages_v4.0.30319_64...
#
#                       Description  \
# 93                            NaN
# 399                           NaN
# 520                           NaN
# 834                           NaN
# 851                           NaN
# ...                           ...
# 997643                        NaN
# 997970                        NaN
# 999441              IP Helper API
# 999629                        NaN
# 999785  Microsoft XmlLite Library
#
#                                                  PipeName
# 93                                                \srvsvc
# 399                                                   NaN
# 520                                                   NaN
# 834     \PSHost.132437237957601629.2316.DefaultAppDoma...
# 851                                                   NaN
# ...                                                   ...
# 997643                                                NaN
# 997970                                                NaN
# 999441  \PSHost.132437237957601629.2316.DefaultAppDoma...
# 999629                                                NaN
# 999785                                            \wkssvc
#
# [2422 rows x 8 columns]

# %%
# Analytic II
II  = (
new_data[features]

[(new_data['Channel'].str.lower() == 'security')
    & (new_data['EventID'] == '4688')
    & (new_data['NewProcessName'].str.lower().str.endswith('powershell.exe', na=False))
    & (~new_data['ParentProcessName'].str.lower().str.endswith('explorer.exe', na=False))
]
)
II
# Out:
#          Channel EventID                                     NewProcessName  \
# 107     Security    4688  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 126     Security    4688  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 230     Security    4688  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 239     Security    4688  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 242     Security    4688  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# ...          ...     ...                                                ...
# 999703  Security    4688  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 999769  Security    4688  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 999770  Security    4688  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 999821  Security    4688  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 999822  Security    4688  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
#
#        ParentProcessName                           Image ImageLoaded  \
# 107                  NaN                             NaN         NaN
# 126                  NaN  C:\Windows\System32\whoami.exe         NaN
# 230                  NaN                             NaN         NaN
# 239                  NaN                             NaN         NaN
# 242                  NaN                             NaN         NaN
# ...                  ...                             ...         ...
# 999703               NaN                             NaN         NaN
# 999769               NaN                             NaN         NaN
# 999770               NaN                             NaN         NaN
# 999821               NaN                             NaN         NaN
# 999822               NaN                             NaN         NaN
#
#              Description PipeName
# 107                  NaN      NaN
# 126                  NaN      NaN
# 230                  NaN      NaN
# 239                  NaN      NaN
# 242                  NaN      NaN
# ...                  ...      ...
# 999703               NaN      NaN
# 999769               NaN      NaN
# 999770  Internet Browser      NaN
# 999821               NaN      NaN
# 999822               NaN      NaN
#
# [12612 rows x 8 columns]

# %%
# Analytic III
III = (
new_data[features]

[(new_data['Channel'] == 'Microsoft-Windows-Sysmon/Operational')
    & (new_data['EventID'] == '1')
    & (new_data['Image'].str.lower().str.endswith('powershell.exe', na=False))
    & (~new_data['ParentImage'].str.lower().str.endswith('explorer.exe', na=False))
]
)
III
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ParentImage'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4956/3301278886.py in <module>
#       6     & (new_data['EventID'] == '1')
#       7     & (new_data['Image'].str.lower().str.endswith('powershell.exe', na=False))
# ----> 8     & (~new_data['ParentImage'].str.lower().str.endswith('explorer.exe', na=False))
#       9 ]
#      10 )
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'ParentImage'

# %%
# Analytic IV
IV = (
new_data[features]

[(new_data['Channel'] == 'Microsoft-Windows-Sysmon/Operational')
    & (new_data['EventID'] == '7')
    & (
        (new_data['Description'].str.lower() == 'system.management.automation')
        | (new_data['ImageLoaded'].str.lower().str.contains('.*system.management.automation.*', regex=True))
    )
]
)
IV
# Out:
#                                      Channel EventID NewProcessName  \
# 458     Microsoft-Windows-Sysmon/Operational       7            NaN
# 707     Microsoft-Windows-Sysmon/Operational       7            NaN
# 1069    Microsoft-Windows-Sysmon/Operational       7            NaN
# 1491    Microsoft-Windows-Sysmon/Operational       7            NaN
# 1558    Microsoft-Windows-Sysmon/Operational       7            NaN
# ...                                      ...     ...            ...
# 996488  Microsoft-Windows-Sysmon/Operational       7            NaN
# 997281  Microsoft-Windows-Sysmon/Operational       7            NaN
# 998109  Microsoft-Windows-Sysmon/Operational       7            NaN
# 998937  Microsoft-Windows-Sysmon/Operational       7            NaN
# 999209  Microsoft-Windows-Sysmon/Operational       7            NaN
#
#        ParentProcessName                                              Image  \
# 458                  NaN                     C:\Windows\System32\whoami.exe
# 707                  NaN  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 1069                 NaN  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 1491                 NaN                    C:\Windows\System32\wscript.exe
# 1558                 NaN  C:\Windows\ADWS\Microsoft.ActiveDirectory.WebS...
# ...                  ...                                                ...
# 996488               NaN                      C:\Windows\System32\lsass.exe
# 997281               NaN                    C:\Windows\System32\wscript.exe
# 998109               NaN                                                NaN
# 998937               NaN                    C:\Windows\System32\wscript.exe
# 999209               NaN                    C:\Windows\System32\wscript.exe
#
#                                               ImageLoaded  \
# 458                                                   NaN
# 707                       C:\Windows\System32\ieframe.dll
# 1069    C:\Windows\assembly\NativeImages_v4.0.30319_64...
# 1491                                                  NaN
# 1558                          C:\Windows\System32\nsi.dll
# ...                                                   ...
# 996488                  C:\Windows\System32\gdi32full.dll
# 997281  C:\Windows\assembly\NativeImages_v4.0.30319_64...
# 998109                    C:\Windows\System32\wmidcom.dll
# 998937                                                NaN
# 999209                    C:\Windows\System32\wmidcom.dll
#
#                                 Description  \
# 458            System.Management.Automation
# 707            System.Management.Automation
# 1069    Windows Script Host Runtime Library
# 1491           System.Management.Automation
# 1558           System.Management.Automation
# ...                                     ...
# 996488         System.Management.Automation
# 997281                  Data Protection API
# 998109         System.Management.Automation
# 998937         System.Management.Automation
# 999209         System.Management.Automation
#
#                                                  PipeName
# 458                                               \wkssvc
# 707     \PSHost.132437237957601629.2316.DefaultAppDoma...
# 1069                                                  NaN
# 1491                                                  NaN
# 1558                                                  NaN
# ...                                                   ...
# 996488                                                NaN
# 997281                                                NaN
# 998109                                                NaN
# 998937                                                NaN
# 999209                                                NaN
#
# [1906 rows x 8 columns]

# %%
# Analytic V
V = (
new_data[features]

[(new_data['Channel'] == 'Microsoft-Windows-Sysmon/Operational')
    & (new_data['EventID'] == '17')
    & (new_data['PipeName'].str.lower().str.startswith('\pshost', na=False))
]
)
V
# Out:
#                                      Channel EventID NewProcessName  \
# 1197    Microsoft-Windows-Sysmon/Operational      17            NaN
# 1357    Microsoft-Windows-Sysmon/Operational      17            NaN
# 2570    Microsoft-Windows-Sysmon/Operational      17            NaN
# 2912    Microsoft-Windows-Sysmon/Operational      17            NaN
# 5266    Microsoft-Windows-Sysmon/Operational      17            NaN
# ...                                      ...     ...            ...
# 993990  Microsoft-Windows-Sysmon/Operational      17            NaN
# 994655  Microsoft-Windows-Sysmon/Operational      17            NaN
# 994774  Microsoft-Windows-Sysmon/Operational      17            NaN
# 998692  Microsoft-Windows-Sysmon/Operational      17            NaN
# 999882  Microsoft-Windows-Sysmon/Operational      17            NaN
#
#        ParentProcessName                                              Image  \
# 1197                 NaN                                                NaN
# 1357                 NaN                                                NaN
# 2570                 NaN                    C:\Windows\System32\svchost.exe
# 2912                 NaN                     C:\Windows\System32\whoami.exe
# 5266                 NaN                     C:\Windows\System32\whoami.exe
# ...                  ...                                                ...
# 993990               NaN                    C:\Windows\System32\svchost.exe
# 994655               NaN                            C:\Windows\explorer.exe
# 994774               NaN                                                NaN
# 998692               NaN                                                NaN
# 999882               NaN  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
#
#                                               ImageLoaded  \
# 1197                      C:\Windows\System32\AppxSip.dll
# 1357    C:\Windows\Microsoft.NET\Framework64\v4.0.3031...
# 2570                C:\Windows\System32\wbem\WmiPrvSE.exe
# 2912    C:\Windows\assembly\NativeImages_v4.0.30319_64...
# 5266    C:\Windows\assembly\NativeImages_v4.0.30319_64...
# ...                                                   ...
# 993990                                                NaN
# 994655                    C:\Windows\System32\wscript.exe
# 994774                   C:\Windows\System32\WinTypes.dll
# 998692                                                NaN
# 999882                   C:\Windows\System32\perfctrs.dll
#
#                                               Description  \
# 1197                                  DHCP Client Service
# 1357                            Microsoft OLE for Windows
# 2570                                                  NaN
# 2912                       Windows NT BASE API Client DLL
# 5266                                                  NaN
# ...                                                   ...
# 993990                                DHCP Client Service
# 994655  Microsoft .NET Runtime Common Language Runtime...
# 994774                                           EDP util
# 998692                                     .NET Framework
# 999882                          Microsoft Property System
#
#                                                  PipeName
# 1197    \PSHost.132437237957601629.2316.DefaultAppDoma...
# 1357    \PSHost.132437237957601629.2316.DefaultAppDoma...
# 2570    \PSHost.132437237957601629.2316.DefaultAppDoma...
# 2912    \PSHost.132437237957601629.2316.DefaultAppDoma...
# 5266    \PSHost.132437237957601629.2316.DefaultAppDoma...
# ...                                                   ...
# 993990  \PSHost.132437237957601629.2316.DefaultAppDoma...
# 994655  \PSHost.132437237957601629.2316.DefaultAppDoma...
# 994774  \PSHost.132437237957601629.2316.DefaultAppDoma...
# 998692  \PSHost.132437237957601629.2316.DefaultAppDoma...
# 999882  \PSHost.132437237957601629.2316.DefaultAppDoma...
#
# [716 rows x 8 columns]

# %%
# Analytic VI
VI = (
new_data[features]

[(new_data['Channel'] == 'Microsoft-Windows-PowerShell/Operational')
    & (new_data['EventID'] == '53504')
]
)
len(VI)
# Out:
# 28

# %% [markdown]
# ### Generate data
# Randomly pick data from each analytic's results, and combine them as the generated dataset.

# %%
# randomly pick from results of analytics
results = [I, II, IV, V, VI]
pick_nums = [230, 230, 230, 230, 28] # 2057 * 2/3 = 1371
gen_data = random_generator(results, pick_nums)

gen_data.shape
# Out:
# (948, 8)

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ### Preprocess data

# %%
# Preprocessing
from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# df = scaler.fit_transform(df)

# %% [markdown]
# ### Training with original data

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold

X = preprocess(df)
X, le_list = labelEncoder_get(X) # record the label encoders for next step
y = labelList(df.shape[0], [876, 1251, 1325, 1370, 1372, 327, 258, 1100, 1106, 913])
clf = DecisionTreeClassifier()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=42)

clf.fit(X_train, y_train)
y_predict = clf.predict(X_test)
print("Balanced accuracy score: {:.2f}".format(metrics.balanced_accuracy_score(y_test, y_predict)))
draw_confusionMatrix(y_test, y_predict)
# Out:
# Balanced accuracy score: 0.50
# C:\Users\ly\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ly\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ly\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       681
#            1       0.00      0.00      0.00         2
#
#     accuracy                           1.00       683
#    macro avg       0.50      0.50      0.50       683
# weighted avg       0.99      1.00      1.00       683

# %% [markdown]
# ### Training with original data and generated data
# Generated data should only be added into trianing set.
#
# Label encoder need to be recorded, otherwise training sets and testing sets may have different labels.

# %%
# preprocess the datasets
X_gen = preprocess(gen_data)
X_gen = labelEncoder_trans(X_gen, le_list)
    
# add generated data to the original training set
X_train_new = pd.concat([X_train, X_gen], axis=0)

# generated data are all positive, y are all 1
for i in range(len(gen_data)):
    y_train.append(1)

clf.fit(X_train_new, y_train)
y_predict = clf.predict(X_test)

print("Balanced accuracy score: {:.2f}".format(metrics.balanced_accuracy_score(y_test, y_predict)))
draw_confusionMatrix(y_test, y_predict)
# Out:
# Balanced accuracy score: 1.00
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       681
#            1       0.67      1.00      0.80         2
#
#     accuracy                           1.00       683
#    macro avg       0.83      1.00      0.90       683
# weighted avg       1.00      1.00      1.00       683

# %%
from sklearn import tree
# draw the tree
plt.figure(figsize=(30, 15))
tree.plot_tree(clf, feature_names=features, fontsize=10)
plt.title("Decision Tree - LocalPwshExecution")
plt.savefig('LocalPwshExecution.png', dpi=100, transparent=True)

# %% [markdown]
# ## Save generated data

# %%
# # extract to JSON file
# dataset.reset_index(drop=True, inplace=True)
gen_data.to_json(r'generated_datasets\\empire_launcher_vbs_new.json', orient='records')

# dataset = json.read_json(path_or_buf=os.getcwd()+ "\\generated_datasets"+ "\\empire_dllinjection_LoadLibrary_CreateRemoteThread_new.json")
# dataset.head()
