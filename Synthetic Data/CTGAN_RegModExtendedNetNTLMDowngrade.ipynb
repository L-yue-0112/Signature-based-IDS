# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from pandas.io import json
from tensorflow import keras
from tensorflow.keras import layers
from sklearn import preprocessing

datasetJSONPath = os.getcwd() + "\\datasets\\empire_monologue_netntlm_downgrade_2019-12-25045202.json"
df = json.read_json(path_or_buf=datasetJSONPath, lines=True)

df.shape
# Out:
# C:\Users\ly\AppData\Roaming\Python\Python37\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\ly\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\ly\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   stacklevel=1)
# (1635, 151)

# %%
# functions definition

from collections import Counter
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt

# Convert integers to strings
def int_to_str(df):
    for column in df.columns:
        # if dtype is int, convert to string , e.g. EventID
        if isinstance(df[column][0], (int, np.int32, np.int64)):
            df[column] = list(map(str, df[column]))
            
    return df
    
# Count NaN in each column in the dataframe
def count_nan(df):
    for column in df.columns:
        num = df[column].isna().sum()
        print(column, str(num))
    return 0

# make a label list of all 0, except the detected threat are 1
def labelList(num, threatIndices):
    y = [0 for x in range(num)]
    for i in threatIndices:
        y[i] =  1
    return y

# Count the items in data frame
def count_items(df):
    for column in df.columns:
        item = df[column]
        print(column, ": ", sorted(Counter(item).items()))
        
    return 0

# replicate specified data to the end of the dataset
def pd_replicate(X, y, rep_list, times=1):
    for index in rep_list:
        for i in range(times):
            
            X = pd.concat([X, pd.DataFrame(X.iloc[index]).T], axis=0, ignore_index=True)

            y.append(1)
    
    return (X, y)
    
# convert object items in the list into strings
def preprocess(df):
    
    # replace NAN with 0
    df = df.replace(np.nan, 0, regex=True)
    
    for column in df.columns:            
        df[column] = list(map(str, df[column]))            
    return df

# fit the dataframe and record the label encoders for each column
def labelEncoder_get(df):
#     le_list = []
    le_dict = {}
    for column in df.columns:
        le = preprocessing.LabelEncoder()
        le.fit(df[column])
        df[column] = le.transform(df[column])
#         le_list.append(le)
        le_dict[column] = le
    return (df, le_dict)

# input the list of label encoders and transform the dataframe
def labelEncoder_trans(df, le_dict):
    for i, column in enumerate(df.columns):
#         le = le_list[i]
        le = le_dict[column]
        df[column] = list(map(str, df[column]))
        df[column] = le.transform(df[column])
    return df

# draw confusin matrix and print the classification report
def draw_confusionMatrix(y_test, y_predict):
    confusion_matrix = metrics.confusion_matrix(y_test, y_predict)
    matrix_df = pd.DataFrame(confusion_matrix)
    ax = plt.axes()
    sns.set(font_scale=1.3)
    plt.figure(figsize=(10, 7))
    sns.heatmap(matrix_df, annot=True, fmt="g", ax=ax, cmap="magma")
    ax.set_title('Confusion Matrix - Decision Tree')
    ax.set_xlabel("Predicted Label", fontsize=15)
    ax.set_ylabel("Actual Label", fontsize=15)
    plt.show()
    print(metrics.classification_report(y_test, y_predict))
    

# Randomly pick data from results and combine them
def random_generator(data_list, pick_nums):
    
    generated_data = pd.DataFrame()
    
    for i, data in enumerate(data_list):
        num = pick_nums[i]
        data_selected = data.sample(num)
        generated_data = pd.concat([generated_data, data_selected], axis=0, ignore_index=True)
    
    return generated_data
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
features = ["Channel", "EventID", "ObjectType", "ObjectName", "ProcessName", "SubjectLogonId", "ObjectValueName", "TargetObject"]
df = df[features]

# change integers to strings to get a better performance in generating new data
df = int_to_str(df)
df.shape
# Out:
# (1635, 8)

# %% [markdown]
# ## Replicate positive data
#
# There are more negative data than positive data, and results from some analytics (e.g. analytics with merging) are less possible to be generated. So we replicate specific positive data to make CTGAN bias to them.

# %% [markdown]
# ## Use CTGAN to generate new data

# %%
from sdv.tabular import CTGAN

# model = CTGAN(cuda=True)
# model.fit(df)

# save and reuse the model
# model.save('RegModExtendedNetNTLMDowngrade.pkl')

model = CTGAN.load(r'models\\RegModExtendedNetNTLMDowngrade.pkl')

# %%
new_data = model.sample(num_rows=1000000)
new_data.head()
# Out:
#                                 Channel EventID ObjectType ObjectName  \
# 0                    Windows PowerShell      12        NaN        NaN
# 1                              Security    4103        NaN        NaN
# 2  Microsoft-Windows-Sysmon/Operational      10        NaN        NaN
# 3                              security      13        NaN        NaN
# 4  Microsoft-Windows-Sysmon/Operational      10        NaN        NaN
#
#                      ProcessName SubjectLogonId       ObjectValueName  \
# 0  C:\Windows\System32\lsass.exe            NaN  LMCompatibilityLevel
# 1                            NaN            NaN                   NaN
# 2                            NaN            NaN                   NaN
# 3                            NaN            NaN      NtlmMinClientSec
# 4                            NaN            NaN                   NaN
#
#                                         TargetObject
# 0                                                NaN
# 1  HKLM\System\CurrentControlSet\Services\DFSR\Pa...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
# # for debugging only
# count_items(preprocess_labelEncoder(df))
# count_items(preprocess_labelEncoder(new_data))

# %% [markdown]
# ## Use hunter program on new data

# %%
# Analytic I
I = (
new_data[["Channel", "EventID", "ObjectType", "ObjectName", "ProcessName", "SubjectLogonId", "ObjectValueName", "TargetObject"]]

[(new_data['Channel'].str.lower() == 'security')
    & (new_data['EventID'].isin(['4663','4656']))
    & (new_data['ObjectType'] == 'Key')
    & (
      (new_data['ObjectName'].str.lower().str.endswith('lsa', na=False))
      | (new_data['ObjectName'].str.lower().str.endswith('lsa\msv1_0', na=False))
    )
    & (~new_data['ProcessName'].str.lower().str.endswith('lsass.exe', na=False))
    & (new_data['SubjectLogonId'] != '0x3e7')
]
)
I
# Out:
#          Channel EventID ObjectType  \
# 87      Security    4656        Key
# 180     security    4656        Key
# 263     security    4656        Key
# 368     security    4663        Key
# 598     security    4663        Key
# ...          ...     ...        ...
# 999586  Security    4663        Key
# 999653  security    4656        Key
# 999864  security    4656        Key
# 999923  security    4656        Key
# 999976  security    4656        Key
#
#                                                ObjectName  \
# 87      \REGISTRY\MACHINE\SYSTEM\ControlSet001\Control...
# 180     \REGISTRY\MACHINE\SYSTEM\ControlSet001\Control...
# 263     \REGISTRY\MACHINE\SYSTEM\ControlSet001\Control...
# 368     \REGISTRY\MACHINE\SYSTEM\ControlSet001\Control...
# 598     \REGISTRY\MACHINE\SYSTEM\ControlSet001\Control...
# ...                                                   ...
# 999586  \REGISTRY\MACHINE\SYSTEM\ControlSet001\Control...
# 999653  \REGISTRY\MACHINE\SYSTEM\ControlSet001\Control...
# 999864  \REGISTRY\MACHINE\SYSTEM\ControlSet001\Control...
# 999923  \REGISTRY\MACHINE\SYSTEM\ControlSet001\Control...
# 999976  \REGISTRY\MACHINE\SYSTEM\ControlSet001\Control...
#
#                                               ProcessName SubjectLogonId  \
# 87                                                      -            0x0
# 180     C:\Windows\System32\WindowsPowerShell\v1.0\pow...        0x49631
# 263     C:\Windows\System32\WindowsPowerShell\v1.0\pow...       0x73f729
# 368                                                     -        0x49631
# 598     C:\Windows\System32\WindowsPowerShell\v1.0\pow...        0x49631
# ...                                                   ...            ...
# 999586                    C:\Windows\System32\svchost.exe        0x49631
# 999653  C:\Windows\System32\WindowsPowerShell\v1.0\pow...            NaN
# 999864                                                NaN        0x49631
# 999923  C:\Windows\System32\WindowsPowerShell\v1.0\pow...        0x49631
# 999976  C:\Windows\System32\WindowsPowerShell\v1.0\pow...          0x3e5
#
#        ObjectValueName TargetObject
# 87                 NaN          NaN
# 180                NaN          NaN
# 263                NaN          NaN
# 368                NaN          NaN
# 598                NaN          NaN
# ...                ...          ...
# 999586             NaN          NaN
# 999653             NaN          NaN
# 999864             NaN          NaN
# 999923             NaN          NaN
# 999976             NaN          NaN
#
# [8341 rows x 8 columns]

# %%
# Analytic II
II  = (
new_data[["Channel", "EventID", "ObjectType", "ObjectName", "ProcessName", "SubjectLogonId", "ObjectValueName", "TargetObject"]]

[(new_data['Channel'].str.lower() == 'security')
    & (new_data['EventID'] == '4657')
    & (new_data['ObjectValueName'].isin(['LMCompatibilityLevel','NtlmMinClientSec','RestrictSendingNTLMTraffic']))
]
)
II
# Out:
#          Channel EventID    ObjectType  \
# 34      security    4657           Key
# 267     security    4657           NaN
# 328     security    4657           NaN
# 457     security    4657           NaN
# 581     security    4657  SecretObject
# ...          ...     ...           ...
# 999688  Security    4657           NaN
# 999703  security    4657           NaN
# 999732  security    4657           NaN
# 999800  security    4657           NaN
# 999997  security    4657           NaN
#
#                                                ObjectName  \
# 34                            Policy\Secrets\$MACHINE.ACC
# 267                                                   NaN
# 328                                                   NaN
# 457                                                   NaN
# 581     \REGISTRY\MACHINE\SYSTEM\ControlSet001\Control...
# ...                                                   ...
# 999688  \REGISTRY\MACHINE\SYSTEM\ControlSet001\Control...
# 999703                                                NaN
# 999732                                                NaN
# 999800                                                NaN
# 999997                                                NaN
#
#                                               ProcessName SubjectLogonId  \
# 34      C:\Windows\System32\WindowsPowerShell\v1.0\pow...        0x49631
# 267                         C:\Windows\System32\lsass.exe          0x3e7
# 328     C:\Windows\System32\WindowsPowerShell\v1.0\pow...          0x3e5
# 457                                                   NaN            NaN
# 581     C:\Windows\System32\WindowsPowerShell\v1.0\pow...        0x49631
# ...                                                   ...            ...
# 999688  C:\Windows\System32\WindowsPowerShell\v1.0\pow...          0x3e5
# 999703                                                NaN            NaN
# 999732                                                NaN            NaN
# 999800                      C:\Windows\System32\lsass.exe            NaN
# 999997                                                  -          0x3e7
#
#                    ObjectValueName TargetObject
# 34      RestrictSendingNTLMTraffic          NaN
# 267               NtlmMinClientSec          NaN
# 328     RestrictSendingNTLMTraffic          NaN
# 457     RestrictSendingNTLMTraffic          NaN
# 581               NtlmMinClientSec          NaN
# ...                            ...          ...
# 999688  RestrictSendingNTLMTraffic          NaN
# 999703  RestrictSendingNTLMTraffic          NaN
# 999732  RestrictSendingNTLMTraffic          NaN
# 999800            NtlmMinClientSec          NaN
# 999997            NtlmMinClientSec          NaN
#
# [10758 rows x 8 columns]

# %%
# Analytic III
III  = (
new_data[["Channel", "EventID", "ObjectType", "ObjectName", "ProcessName", "SubjectLogonId", "ObjectValueName", "TargetObject"]]

[(new_data['Channel'] == 'Microsoft-Windows-Sysmon/Operational')
    & (new_data['EventID'] == '13')
    & (
      (new_data['TargetObject'].str.endswith('LMCompatibilityLevel', na=False))
      | (new_data['TargetObject'].str.endswith('NtlmMinClientSec', na=False))
      | (new_data['TargetObject'].str.endswith('RestrictSendingNTLMTraffic', na=False))
    )
]
)
III
# Out:
#                                      Channel EventID ObjectType  \
# 2889    Microsoft-Windows-Sysmon/Operational      13        NaN
# 4313    Microsoft-Windows-Sysmon/Operational      13        NaN
# 6021    Microsoft-Windows-Sysmon/Operational      13        NaN
# 10673   Microsoft-Windows-Sysmon/Operational      13        NaN
# 14050   Microsoft-Windows-Sysmon/Operational      13        NaN
# ...                                      ...     ...        ...
# 929494  Microsoft-Windows-Sysmon/Operational      13        NaN
# 934647  Microsoft-Windows-Sysmon/Operational      13        NaN
# 953194  Microsoft-Windows-Sysmon/Operational      13        NaN
# 959363  Microsoft-Windows-Sysmon/Operational      13        NaN
# 961079  Microsoft-Windows-Sysmon/Operational      13        NaN
#
#                                                ObjectName  \
# 2889                                                  NaN
# 4313                                                  NaN
# 6021                                                  NaN
# 10673                                                 NaN
# 14050                                                 NaN
# ...                                                   ...
# 929494  \REGISTRY\MACHINE\SYSTEM\ControlSet001\Control...
# 934647                                                NaN
# 953194                                                NaN
# 959363                                                NaN
# 961079                                                NaN
#
#                           ProcessName SubjectLogonId  \
# 2889                              NaN            NaN
# 4313                              NaN            NaN
# 6021                              NaN            NaN
# 10673                               -          0x3e7
# 14050                             NaN        0x49631
# ...                               ...            ...
# 929494  C:\Windows\System32\lsass.exe            NaN
# 934647                            NaN       0x73f729
# 953194                            NaN            NaN
# 959363                            NaN            NaN
# 961079                            NaN          0x3e7
#
#                    ObjectValueName  \
# 2889    RestrictSendingNTLMTraffic
# 4313    RestrictSendingNTLMTraffic
# 6021                           NaN
# 10673   RestrictSendingNTLMTraffic
# 14050   RestrictSendingNTLMTraffic
# ...                            ...
# 929494  RestrictSendingNTLMTraffic
# 934647                         NaN
# 953194                         NaN
# 959363                         NaN
# 961079  RestrictSendingNTLMTraffic
#
#                                              TargetObject
# 2889    HKLM\System\CurrentControlSet\Control\Lsa\MSV1...
# 4313    HKLM\System\CurrentControlSet\Control\Lsa\MSV1...
# 6021    HKLM\System\CurrentControlSet\Control\Lsa\MSV1...
# 10673   HKLM\System\CurrentControlSet\Control\Lsa\MSV1...
# 14050   HKLM\System\CurrentControlSet\Control\Lsa\MSV1...
# ...                                                   ...
# 929494  HKLM\System\CurrentControlSet\Control\Lsa\MSV1...
# 934647  HKLM\System\CurrentControlSet\Control\Lsa\MSV1...
# 953194  HKLM\System\CurrentControlSet\Control\Lsa\LMCo...
# 959363  HKLM\System\CurrentControlSet\Control\Lsa\LMCo...
# 961079  HKLM\System\CurrentControlSet\Control\Lsa\MSV1...
#
# [118 rows x 8 columns]

# %% [markdown]
# ### Generate data
# Randomly pick data from each analytic's results, and combine them as the generated dataset.

# %%
# randomly pick from results of analytics
results = [I, II, III]
pick_nums = [400, 400, 118]
gen_data = random_generator(results, pick_nums)

gen_data.shape
# Out:
# (918, 8)

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ### Preprocess data

# %%
# Preprocessing
from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# df = scaler.fit_transform(df)

# %% [markdown]
# ### Original data

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold

# X = preprocess_labelEncoder(df)
X = preprocess(df)
X, le_dict = labelEncoder_get(X)
y = labelList(df.shape[0], [550, 552, 553, 556, 581, 589, 592, 601, 642, 651, 655, 665, 564, 579, 591, 611, 615, 376, 504, 505, 546, 549])

clf = DecisionTreeClassifier()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=42)

clf.fit(X_train, y_train)
y_predict = clf.predict(X_test)
print("Balanced accuracy score: {:.2f}".format(metrics.balanced_accuracy_score(y_test, y_predict)))
draw_confusionMatrix(y_test, y_predict)
# Out:
# Balanced accuracy score: 1.00
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       535
#            1       1.00      1.00      1.00         5
#
#     accuracy                           1.00       540
#    macro avg       1.00      1.00      1.00       540
# weighted avg       1.00      1.00      1.00       540

# %% [markdown]
# Got good performance by only using the original dataset, there's no requirement to generate fake data.

# %% [markdown]
# ### Original data with generated data
# Generated data should only be added into trianing set.

# %%
X_gen = preprocess(gen_data)
X_gen = labelEncoder_trans(X_gen, le_dict)
# add generated data to the original training set
X_train_new = pd.concat([X_train, X_gen], axis=0)

# generated data are all positive
for i in range(len(gen_data)):
    y_train.append(1)

clf = DecisionTreeClassifier()

clf.fit(X_train_new, y_train)
y_predict = clf.predict(X_test)
print("Balanced accuracy score: {:.2f}".format(metrics.balanced_accuracy_score(y_test, y_predict)))
draw_confusionMatrix(y_test, y_predict)
# Out:
# Balanced accuracy score: 1.00
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       535
#            1       0.83      1.00      0.91         5
#
#     accuracy                           1.00       540
#    macro avg       0.92      1.00      0.95       540
# weighted avg       1.00      1.00      1.00       540

# %%
# draw the tree
from sklearn import tree

plt.figure(figsize=(30, 15))
tree.plot_tree(clf, feature_names=features, fontsize=10)
plt.title("Decision Tree - RegModExtendedNetNTLMDowngrade")
plt.savefig(r'DecisionTree\RegModExtendedNetNTLMDowngrade.png', dpi=100, transparent=True)

# %% [markdown]
# ## Save generated data

# %%
# # extract to JSON file
# dataset.reset_index(drop=True, inplace=True)
gen_data.to_json(os.getcwd() + r'\generated_datasets\eempire_monologue_netntlm_downgrade_new.json', orient='records')

# dataset = json.read_json(path_or_buf=os.getcwd()+ "\\generated_datasets"+ "\\empire_dllinjection_LoadLibrary_CreateRemoteThread_new.json")
# dataset.head()
