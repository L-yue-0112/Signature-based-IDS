# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from pandas.io import json
from tensorflow import keras
from tensorflow.keras import layers
from sklearn import preprocessing

datasetJSONPath = os.getcwd() + "\\datasets\\empire_psremoting_stager_2020-09-20170827.json"
df = json.read_json(path_or_buf=datasetJSONPath, lines=True)

df.shape
# Out:
# C:\Users\ly\AppData\Roaming\Python\Python37\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\ly\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\ly\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   stacklevel=1)
# (2744, 177)

# %%
# functions definition

from collections import Counter
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt

# Convert integers to strings
def int_to_str(df):
    for column in df.columns:
        # if dtype is int, convert to string , e.g. EventID
        if isinstance(df[column][0], (int, np.int32, np.int64)):
            df[column] = list(map(str, df[column]))
            
    return df
    
# Count NaN in each column in the dataframe
def count_nan(df):
    for column in df.columns:
        num = df[column].isna().sum()
        print(column, str(num))
    return 0

# make a label list of all 0, except the detected threat are 1
def labelList(num, threatIndices):
    y = [0 for x in range(num)]
    for i in threatIndices:
        y[i] =  1
    return y

# Count the items in data frame
def count_items(df):
    for column in df.columns:
        item = df[column]
        print(column, ": ", sorted(Counter(item).items()))
        
    return 0

# replicate specified data to the end of the dataset
def pd_replicate(X, y, rep_list, times=1):
    for index in rep_list:
        for i in range(times):
            
            X = pd.concat([X, pd.DataFrame(X.iloc[index]).T], axis=0, ignore_index=True)

            y.append(1)
    
    return (X, y)
    
# convert object items in the list into strings
def preprocess(df):
    
    # replace NAN with 0
    df = df.replace(np.nan, 0, regex=True)
    
    for column in df.columns:            
        df[column] = list(map(str, df[column]))            
    return df

# fit the dataframe and record the label encoders for each column
def labelEncoder_get(df):
    le_dict = {}
    for column in df.columns:
        le = preprocessing.LabelEncoder()
        le.fit(df[column])
        df[column] = le.transform(df[column])
        le_dict[column] = le
    return (df, le_dict)

# input the list of label encoders and transform the dataframe
def labelEncoder_trans(df, le_dict):
    for i, column in enumerate(df.columns):
        le = le_dict[column]
        df[column] = list(map(str, df[column]))
        df[column] = le.transform(df[column])
    return df

# draw confusin matrix and print the classification report
def draw_confusionMatrix(y_test, y_predict):
    confusion_matrix = metrics.confusion_matrix(y_test, y_predict)
    matrix_df = pd.DataFrame(confusion_matrix)
    ax = plt.axes()
    sns.set(font_scale=1.3)
    plt.figure(figsize=(10, 7))
    sns.heatmap(matrix_df, annot=True, fmt="g", ax=ax, cmap="magma")
    ax.set_title('Confusion Matrix - Decision Tree')
    ax.set_xlabel("Predicted Label", fontsize=15)
    ax.set_ylabel("Actual Label", fontsize=15)
    plt.show()
    print(metrics.classification_report(y_test, y_predict))
    

# Randomly pick data from results and combine them
def random_generator(data_list, pick_nums):
    
    generated_data = pd.DataFrame()
    
    for i, data in enumerate(data_list):
        num = pick_nums[i]
        data_selected = data.sample(num, replace=True)
        generated_data = pd.concat([generated_data, data_selected], axis=0, ignore_index=True)
    
    return generated_data

# split the training and testing sets manually, make sure that positive data is in the testing set
def train_test_split_m(X, y, positive_list, test_size=0.33):

    sample_len = int(len(X) * 0.33 - len(positive_list))
    
    X_test = X.iloc[positive_list]
    X = X.drop(positive_list)
    
    X_random = X.sample(sample_len)
    X = X.drop(X_random.index)
    X_test = pd.concat([X_test, X_random], axis=0, ignore_index=True)
    y_test = list([1 for i in range(len(positive_list))] + [0 for i in range(sample_len)])

    X_train = X
    y_train = [0 for i in range(len(X_train))]
    
    return (X_train, X_test, y_train, y_test)

# %%
features = ["Channel", "EventID", "Message", "DestPort", "LayerRTID", "ParentProcessName", "NewProcessName", "ParentImage", "Image", "DestinationPort", "User"]
df = df[features]

# change integers to strings to get a better performance in generating new data
df = int_to_str(df)
df.shape
# Out:
# (2744, 11)

# %% [markdown]
# ## Replicate positive data
#
# There are more negative data than positive data, and results from some analytics (e.g. analytics with merging) are less possible to be generated. So we replicate specific positive data to make CTGAN bias to them.

# %% [markdown]
# ## Use CTGAN to generate new data

# %%
from sdv.tabular import CTGAN

# model = CTGAN(cuda=True)
# model.fit(df)
# save and reuse the model
# model.save('RemotePwshExecution.pkl')

model = CTGAN.load(r'models\\RemotePwshExecution.pkl')

# %%
new_data = model.sample(num_rows=1000000)
new_data.head()
# Out:
#                                 Channel EventID  \
# 0  Microsoft-Windows-Sysmon/Operational      12
# 1  Microsoft-Windows-Sysmon/Operational      23
# 2  Microsoft-Windows-Sysmon/Operational      10
# 3  Microsoft-Windows-Sysmon/Operational      12
# 4                    Windows PowerShell    4688
#
#                                              Message  DestPort  LayerRTID  \
# 0                                                NaN       NaN        NaN
# 1  Provider "Variable" is Started. \r\n\r\nDetail...       NaN        NaN
# 2  The handle to an object was closed.\r\n\r\nSub...       NaN        NaN
# 3                                                NaN       NaN        NaN
# 4                                                NaN       NaN        NaN
#
#   ParentProcessName NewProcessName ParentImage  \
# 0               NaN            NaN         NaN
# 1               NaN            NaN         NaN
# 2               NaN            NaN         NaN
# 3               NaN            NaN         NaN
# 4               NaN            NaN         NaN
#
#                              Image  DestinationPort  \
# 0                              NaN              NaN
# 1                              NaN              NaN
# 2   C:\Windows\System32\whoami.exe              NaN
# 3  C:\windows\system32\svchost.exe              NaN
# 4  C:\Windows\System32\svchost.exe              NaN
#
#                            User
# 0                           NaN
# 1  NT AUTHORITY\NETWORK SERVICE
# 2           NT AUTHORITY\SYSTEM
# 3                           NaN
# 4                           NaN

# %%
# # for debugging only
# count_items(preprocess_labelEncoder(df))
# Counter(new_data['DestPort']).items()

# %% [markdown]
# ## Use hunter program on new data

# %%
# Analytic I
I = (
new_data[features]

[(new_data['Channel'].isin(['Microsoft-Windows-PowerShell/Operational','Windows PowerShell']))
    & (new_data['EventID'].isin(['400','4103']))
    & (new_data['Message'].str.contains('.*HostApplication.*wsmprovhost.*', regex=True))
]
)
I
# Out:
#                                          Channel EventID  \
# 42      Microsoft-Windows-PowerShell/Operational    4103
# 2437                          Windows PowerShell    4103
# 32883                         Windows PowerShell    4103
# 68214                         Windows PowerShell    4103
# 91116                         Windows PowerShell    4103
# 103326                        Windows PowerShell    4103
# 104919                        Windows PowerShell    4103
# 133226                        Windows PowerShell    4103
# 201374                        Windows PowerShell    4103
# 223346                        Windows PowerShell    4103
# 274262                        Windows PowerShell    4103
# 298220  Microsoft-Windows-PowerShell/Operational    4103
# 299972                        Windows PowerShell    4103
# 303196                        Windows PowerShell    4103
# 325013  Microsoft-Windows-PowerShell/Operational    4103
# 336242                        Windows PowerShell    4103
# 378052                        Windows PowerShell     400
# 382017                        Windows PowerShell    4103
# 409857                        Windows PowerShell    4103
# 412891  Microsoft-Windows-PowerShell/Operational    4103
# 427785  Microsoft-Windows-PowerShell/Operational    4103
# 446688                        Windows PowerShell    4103
# 533077                        Windows PowerShell    4103
# 561266                        Windows PowerShell    4103
# 593963  Microsoft-Windows-PowerShell/Operational    4103
# 664918  Microsoft-Windows-PowerShell/Operational    4103
# 669967                        Windows PowerShell    4103
# 670750                        Windows PowerShell    4103
# 708105                        Windows PowerShell    4103
# 734358  Microsoft-Windows-PowerShell/Operational    4103
# 742705                        Windows PowerShell    4103
# 744325                        Windows PowerShell    4103
# 745617                        Windows PowerShell    4103
# 774007                        Windows PowerShell    4103
# 776034  Microsoft-Windows-PowerShell/Operational    4103
# 795732                        Windows PowerShell    4103
# 843751                        Windows PowerShell    4103
# 854438                        Windows PowerShell    4103
# 858402  Microsoft-Windows-PowerShell/Operational    4103
# 860506                        Windows PowerShell    4103
# 874832                        Windows PowerShell    4103
# 894735  Microsoft-Windows-PowerShell/Operational    4103
# 912029                        Windows PowerShell    4103
# 924354                        Windows PowerShell    4103
# 972764                        Windows PowerShell    4103
# 974856                        Windows PowerShell    4103
#
#                                                   Message  DestPort  \
# 42      Engine state is changed from None to Available...       NaN
# 2437    Provider "FileSystem" is Started. \r\n\r\nDeta...       NaN
# 32883   Provider "Variable" is Started. \r\n\r\nDetail...       NaN
# 68214   Provider "FileSystem" is Started. \r\n\r\nDeta...       NaN
# 91116   Provider "FileSystem" is Started. \r\n\r\nDeta...       NaN
# 103326  Provider "Registry" is Started. \r\n\r\nDetail...       NaN
# 104919  Provider "FileSystem" is Started. \r\n\r\nDeta...       NaN
# 133226  Provider "Environment" is Started. \r\n\r\nDet...       NaN
# 201374  Provider "FileSystem" is Started. \r\n\r\nDeta...       NaN
# 223346  Provider "Variable" is Started. \r\n\r\nDetail...       NaN
# 274262  Provider "Environment" is Started. \r\n\r\nDet...       NaN
# 298220  Provider "Environment" is Started. \r\n\r\nDet...       NaN
# 299972  Provider "Environment" is Started. \r\n\r\nDet...       NaN
# 303196  Provider "Environment" is Started. \r\n\r\nDet...       NaN
# 325013  Provider "Function" is Started. \r\n\r\nDetail...       NaN
# 336242  Provider "Variable" is Started. \r\n\r\nDetail...       NaN
# 378052  Provider "Function" is Started. \r\n\r\nDetail...       NaN
# 382017  Provider "FileSystem" is Started. \r\n\r\nDeta...       NaN
# 409857  Provider "Variable" is Started. \r\n\r\nDetail...       NaN
# 412891  Provider "Variable" is Started. \r\n\r\nDetail...       NaN
# 427785  Provider "Variable" is Started. \r\n\r\nDetail...       NaN
# 446688  Provider "Function" is Started. \r\n\r\nDetail...       NaN
# 533077  Provider "Variable" is Started. \r\n\r\nDetail...       NaN
# 561266  Provider "Variable" is Started. \r\n\r\nDetail...       NaN
# 593963  Provider "Environment" is Started. \r\n\r\nDet...       NaN
# 664918  Provider "Registry" is Started. \r\n\r\nDetail...       NaN
# 669967  Provider "Environment" is Started. \r\n\r\nDet...       NaN
# 670750  Provider "Alias" is Started. \r\n\r\nDetails: ...       NaN
# 708105  Provider "Alias" is Started. \r\n\r\nDetails: ...       NaN
# 734358  Provider "FileSystem" is Started. \r\n\r\nDeta...       NaN
# 742705  Provider "FileSystem" is Started. \r\n\r\nDeta...       NaN
# 744325  Provider "FileSystem" is Started. \r\n\r\nDeta...       NaN
# 745617  Provider "Function" is Started. \r\n\r\nDetail...       NaN
# 774007  Provider "FileSystem" is Started. \r\n\r\nDeta...       NaN
# 776034  Provider "Environment" is Started. \r\n\r\nDet...       NaN
# 795732  Provider "FileSystem" is Started. \r\n\r\nDeta...       NaN
# 843751  Provider "Variable" is Started. \r\n\r\nDetail...       NaN
# 854438  Provider "Variable" is Started. \r\n\r\nDetail...       NaN
# 858402  Engine state is changed from None to Available...       NaN
# 860506  Provider "FileSystem" is Started. \r\n\r\nDeta...       NaN
# 874832  Provider "Registry" is Started. \r\n\r\nDetail...       NaN
# 894735  Provider "Registry" is Started. \r\n\r\nDetail...       NaN
# 912029  Provider "Variable" is Started. \r\n\r\nDetail...       NaN
# 924354  Provider "Registry" is Started. \r\n\r\nDetail...       NaN
# 972764  Provider "Environment" is Started. \r\n\r\nDet...       NaN
# 974856  Provider "Variable" is Started. \r\n\r\nDetail...       NaN
#
#         LayerRTID                    ParentProcessName  \
# 42            NaN                                  NaN
# 2437          NaN                                  NaN
# 32883        40.0                                  NaN
# 68214         NaN                                  NaN
# 91116         NaN                                  NaN
# 103326        NaN                                  NaN
# 104919        NaN                                  NaN
# 133226        NaN                                  NaN
# 201374        NaN                                  NaN
# 223346        NaN                                  NaN
# 274262        NaN                                  NaN
# 298220        NaN                                  NaN
# 299972       40.0                                  NaN
# 303196        NaN                                  NaN
# 325013        NaN                                  NaN
# 336242        NaN                                  NaN
# 378052        NaN                                  NaN
# 382017        NaN                                  NaN
# 409857        NaN                                  NaN
# 412891        NaN                                  NaN
# 427785        NaN                                  NaN
# 446688        NaN                                  NaN
# 533077        NaN                                  NaN
# 561266        NaN                                  NaN
# 593963        NaN                                  NaN
# 664918        NaN                                  NaN
# 669967        NaN                                  NaN
# 670750        NaN                                  NaN
# 708105        NaN      C:\Windows\System32\svchost.exe
# 734358        NaN                                  NaN
# 742705        NaN                                  NaN
# 744325        NaN                                  NaN
# 745617        NaN                                  NaN
# 774007        NaN                                  NaN
# 776034        NaN                                  NaN
# 795732        NaN                                  NaN
# 843751        NaN                                  NaN
# 854438        NaN                                  NaN
# 858402       40.0                                  NaN
# 860506        NaN      C:\Windows\System32\svchost.exe
# 874832       37.0                                  NaN
# 894735        NaN                                  NaN
# 912029        NaN                                  NaN
# 924354        NaN                                  NaN
# 972764        NaN                                  NaN
# 974856        NaN  C:\Windows\System32\wsmprovhost.exe
#
#                              NewProcessName  \
# 42                                      NaN
# 2437                                    NaN
# 32883                                   NaN
# 68214                                   NaN
# 91116                                   NaN
# 103326                                  NaN
# 104919                                  NaN
# 133226                                  NaN
# 201374                                  NaN
# 223346                                  NaN
# 274262                                  NaN
# 298220                                  NaN
# 299972  C:\Windows\System32\wsmprovhost.exe
# 303196                                  NaN
# 325013                                  NaN
# 336242                                  NaN
# 378052                                  NaN
# 382017                                  NaN
# 409857                                  NaN
# 412891                                  NaN
# 427785                                  NaN
# 446688                                  NaN
# 533077                                  NaN
# 561266                                  NaN
# 593963                                  NaN
# 664918                                  NaN
# 669967                                  NaN
# 670750                                  NaN
# 708105                                  NaN
# 734358                                  NaN
# 742705                                  NaN
# 744325                                  NaN
# 745617                                  NaN
# 774007                                  NaN
# 776034                                  NaN
# 795732                                  NaN
# 843751                                  NaN
# 854438                                  NaN
# 858402                                  NaN
# 860506                                  NaN
# 874832                                  NaN
# 894735                                  NaN
# 912029                                  NaN
# 924354                                  NaN
# 972764                                  NaN
# 974856                                  NaN
#
#                                               ParentImage  \
# 42                                                    NaN
# 2437                                                  NaN
# 32883                                                 NaN
# 68214                                                 NaN
# 91116                                                 NaN
# 103326                                                NaN
# 104919                                                NaN
# 133226                                                NaN
# 201374                C:\Windows\System32\wsmprovhost.exe
# 223346                                                NaN
# 274262  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 298220                                                NaN
# 299972                                                NaN
# 303196                                                NaN
# 325013  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 336242                                                NaN
# 378052                                                NaN
# 382017                                                NaN
# 409857                                                NaN
# 412891                                                NaN
# 427785                                                NaN
# 446688  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 533077                C:\Windows\System32\wsmprovhost.exe
# 561266                                                NaN
# 593963  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 664918                                                NaN
# 669967                                                NaN
# 670750                                                NaN
# 708105                C:\Windows\System32\wsmprovhost.exe
# 734358  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 742705                                                NaN
# 744325                                                NaN
# 745617                                                NaN
# 774007                                                NaN
# 776034  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 795732                                                NaN
# 843751                                                NaN
# 854438                                                NaN
# 858402                                                NaN
# 860506                                                NaN
# 874832                                                NaN
# 894735  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 912029                                                NaN
# 924354                                                NaN
# 972764                                                NaN
# 974856                                                NaN
#
#                                                     Image  DestinationPort  \
# 42      C:\WindowsAzure\GuestAgent_2.7.41491.993_2020-...              NaN
# 2437    C:\Packages\Plugins\Microsoft.Azure.NetworkWat...              NaN
# 32883                                                 NaN              NaN
# 68214                                                 NaN              NaN
# 91116                                                 NaN              NaN
# 103326                                                NaN              NaN
# 104919                                                NaN              NaN
# 133226  C:\windows\System32\WindowsPowerShell\v1.0\pow...              NaN
# 201374              C:\Windows\System32\wbem\WmiPrvSE.exe              NaN
# 223346                                                NaN              NaN
# 274262                                                NaN              NaN
# 298220                                                NaN              NaN
# 299972                                                NaN              NaN
# 303196                    C:\windows\System32\svchost.exe              NaN
# 325013                                                NaN              NaN
# 336242                                                NaN              NaN
# 378052  C:\WindowsAzure\GuestAgent_2.7.41491.993_2020-...              NaN
# 382017                                                NaN              NaN
# 409857                                                NaN              NaN
# 412891                                             System              NaN
# 427785                                                NaN              NaN
# 446688                    C:\windows\System32\svchost.exe              NaN
# 533077  C:\Packages\Plugins\Microsoft.Azure.NetworkWat...              NaN
# 561266                                                NaN              NaN
# 593963                                                NaN              NaN
# 664918                                                NaN              NaN
# 669967                                                NaN              NaN
# 670750                                                NaN              NaN
# 708105              C:\Windows\System32\wbem\WmiPrvSE.exe              NaN
# 734358                                                NaN              NaN
# 742705                                                NaN              NaN
# 744325                                                NaN              NaN
# 745617                                                NaN              NaN
# 774007                                                NaN              NaN
# 776034                                                NaN              NaN
# 795732                                                NaN              NaN
# 843751                                                NaN              NaN
# 854438                                                NaN              NaN
# 858402                                                NaN              NaN
# 860506                                                NaN              NaN
# 874832                                                NaN              NaN
# 894735                                                NaN              NaN
# 912029                                                NaN              NaN
# 924354                                                NaN              NaN
# 972764                                                NaN              NaN
# 974856                                                NaN              NaN
#
#                                 User
# 42                               NaN
# 2437                             NaN
# 32883   NT AUTHORITY\NETWORK SERVICE
# 68214                            NaN
# 91116                            NaN
# 103326                           NaN
# 104919                           NaN
# 133226                           NaN
# 201374                           NaN
# 223346                           NaN
# 274262                           NaN
# 298220                           NaN
# 299972                           NaN
# 303196                           NaN
# 325013                           NaN
# 336242                           NaN
# 378052                           NaN
# 382017                           NaN
# 409857                           NaN
# 412891           NT AUTHORITY\SYSTEM
# 427785           NT AUTHORITY\SYSTEM
# 446688                           NaN
# 533077                           NaN
# 561266                           NaN
# 593963                           NaN
# 664918                           NaN
# 669967                           NaN
# 670750                           NaN
# 708105                           NaN
# 734358                           NaN
# 742705                           NaN
# 744325                           NaN
# 745617                           NaN
# 774007                           NaN
# 776034                           NaN
# 795732                           NaN
# 843751                           NaN
# 854438                           NaN
# 858402                           NaN
# 860506                           NaN
# 874832                           NaN
# 894735                           NaN
# 912029                           NaN
# 924354                           NaN
# 972764                           NaN
# 974856                           NaN

# %%
# Analytic II
II  = (
new_data[features]

[(new_data['Channel'].str.lower() == 'security')
    & (new_data['EventID'] == '5156')
    & (
        (new_data['DestPort'] == 5985)
        | (new_data['DestPort'] == 5986)
    )
#     & (new_data['LayerRTID'] == 44)
]
# [((new_data['DestPort'] == 5985)
#     | (new_data['DestPort'] == 5986)
#     | (new_data['DestPort'] == '3617.0'))
# ]
)
II
# Out:
# Empty DataFrame
# Columns: [Channel, EventID, Message, DestPort, LayerRTID, ParentProcessName, NewProcessName, ParentImage, Image, DestinationPort, User]
# Index: []

# %%
# Analytic III
III = (
new_data[features]

[(new_data['Channel'].str.lower() == 'security')
    & (new_data['EventID'] == '4688')
    & (
        (new_data['ParentProcessName'].str.lower().str.endswith('wsmprovhost.exe', na=False))
        | (new_data['NewProcessName'].str.lower().str.endswith('wsmprovhost.exe', na=False))
    )
]
)
III
# Out:
#          Channel EventID                                            Message  \
# 92      Security    4688  The Windows Filtering Platform has permitted a...
# 126     security    4688  A handle to an object was requested.\r\n\r\nSu...
# 829     security    4688  Provider "Environment" is Started. \r\n\r\nDet...
# 1084    security    4688  The Windows Filtering Platform has permitted a...
# 1585    security    4688                                                NaN
# ...          ...     ...                                                ...
# 997807  security    4688  An attempt was made to duplicate a handle to a...
# 998005  security    4688  The Windows Filtering Platform has permitted a...
# 999412  security    4688  Pipeline execution details for command line:  ...
# 999475  security    4688  The handle to an object was closed.\r\n\r\nSub...
# 999714  security    4688  An attempt was made to access an object.\r\n\r...
#
#         DestPort  LayerRTID                    ParentProcessName  \
# 92           NaN       37.0  C:\Windows\System32\wsmprovhost.exe
# 126          NaN       40.0                                  NaN
# 829          NaN       40.0  C:\Windows\System32\wsmprovhost.exe
# 1084         NaN       40.0  C:\Windows\System32\wsmprovhost.exe
# 1585         NaN        NaN      C:\Windows\System32\svchost.exe
# ...          ...        ...                                  ...
# 997807       NaN        NaN  C:\Windows\System32\wsmprovhost.exe
# 998005       NaN        NaN  C:\Windows\System32\wsmprovhost.exe
# 999412       NaN        NaN  C:\Windows\System32\wsmprovhost.exe
# 999475       NaN       40.0                                  NaN
# 999714       NaN       40.0  C:\Windows\System32\wsmprovhost.exe
#
#                              NewProcessName ParentImage  \
# 92          C:\Windows\System32\conhost.exe         NaN
# 126     C:\Windows\System32\wsmprovhost.exe         NaN
# 829                                     NaN         NaN
# 1084                                    NaN         NaN
# 1585    C:\Windows\System32\wsmprovhost.exe         NaN
# ...                                     ...         ...
# 997807                                  NaN         NaN
# 998005                                  NaN         NaN
# 999412      C:\Windows\System32\conhost.exe         NaN
# 999475  C:\Windows\System32\wsmprovhost.exe         NaN
# 999714                                  NaN         NaN
#
#                                                     Image  DestinationPort  \
# 92                                                    NaN              NaN
# 126                       C:\windows\system32\svchost.exe              NaN
# 829                                                   NaN              NaN
# 1084                                                  NaN              NaN
# 1585                                                  NaN              NaN
# ...                                                   ...              ...
# 997807                                                NaN              NaN
# 998005                                                NaN              NaN
# 999412  C:\Packages\Plugins\Microsoft.Azure.NetworkWat...              NaN
# 999475                                                NaN              NaN
# 999714                                                NaN              NaN
#
#        User
# 92      NaN
# 126     NaN
# 829     NaN
# 1084    NaN
# 1585    NaN
# ...     ...
# 997807  NaN
# 998005  NaN
# 999412  NaN
# 999475  NaN
# 999714  NaN
#
# [2477 rows x 11 columns]

# %%
# Analytic IV
IV = (
new_data[features]

[(new_data['Channel'] == 'Microsoft-Windows-Sysmon/Operational')
    & (new_data['EventID'] == '1')
    & (
        (new_data['ParentImage'].str.lower().str.endswith('wsmprovhost.exe', na=False))
        | (new_data['Image'].str.lower().str.endswith('wsmprovhost.exe', na=False))
    )
]
)
IV
# Out:
#                                      Channel EventID Message  DestPort  \
# 1040    Microsoft-Windows-Sysmon/Operational       1     NaN       NaN
# 1360    Microsoft-Windows-Sysmon/Operational       1     NaN       NaN
# 2306    Microsoft-Windows-Sysmon/Operational       1     NaN       NaN
# 3498    Microsoft-Windows-Sysmon/Operational       1     NaN       NaN
# 3627    Microsoft-Windows-Sysmon/Operational       1     NaN       NaN
# ...                                      ...     ...     ...       ...
# 993058  Microsoft-Windows-Sysmon/Operational       1     NaN       NaN
# 994143  Microsoft-Windows-Sysmon/Operational       1     NaN       NaN
# 998584  Microsoft-Windows-Sysmon/Operational       1     NaN       NaN
# 998600  Microsoft-Windows-Sysmon/Operational       1     NaN       NaN
# 999408  Microsoft-Windows-Sysmon/Operational       1     NaN       NaN
#
#         LayerRTID ParentProcessName NewProcessName ParentImage  \
# 1040          NaN               NaN            NaN         NaN
# 1360          NaN               NaN            NaN         NaN
# 2306          NaN               NaN            NaN         NaN
# 3498          NaN               NaN            NaN         NaN
# 3627          NaN               NaN            NaN         NaN
# ...           ...               ...            ...         ...
# 993058        NaN               NaN            NaN         NaN
# 994143        NaN               NaN            NaN         NaN
# 998584        NaN               NaN            NaN         NaN
# 998600        NaN               NaN            NaN         NaN
# 999408        NaN               NaN            NaN         NaN
#
#                                       Image  DestinationPort  \
# 1040    C:\windows\system32\wsmprovhost.exe           3626.0
# 1360    C:\windows\system32\wsmprovhost.exe              NaN
# 2306    C:\windows\system32\wsmprovhost.exe              NaN
# 3498    C:\windows\system32\wsmprovhost.exe              NaN
# 3627    C:\windows\system32\wsmprovhost.exe              NaN
# ...                                     ...              ...
# 993058  C:\Windows\System32\wsmprovhost.exe              NaN
# 994143  C:\windows\system32\wsmprovhost.exe              NaN
# 998584  C:\Windows\System32\wsmprovhost.exe              NaN
# 998600  C:\windows\system32\wsmprovhost.exe              NaN
# 999408  C:\windows\system32\wsmprovhost.exe              NaN
#
#                      User
# 1040                  NaN
# 1360                  NaN
# 2306                  NaN
# 3498                  NaN
# 3627    THESHIRE\pgustavo
# ...                   ...
# 993058                NaN
# 994143                NaN
# 998584                NaN
# 998600                NaN
# 999408                NaN
#
# [766 rows x 11 columns]

# %%
# Analytic V
V = (
new_data[features]

[(new_data['Channel'] == 'Microsoft-Windows-Sysmon/Operational')
    & (new_data['EventID'] == '3')
    & (
        (new_data['DestinationPort'] == 5985)
        | (new_data['DestinationPort'] == 5986)
    )
    & (~new_data['User'].isin(['NT AUTHORITY\\NETWORK SERVICE', 'NT AUTHORITY\\SYSTEM']))
]
)
V
# Out:
# Empty DataFrame
# Columns: [Channel, EventID, Message, DestPort, LayerRTID, ParentProcessName, NewProcessName, ParentImage, Image, DestinationPort, User]
# Index: []

# %% [markdown]
# ### Generate data
# Randomly pick data from each analytic's results, and combine them as the generated dataset.

# %%
# randomly pick from results of analytics
results = [I, III, IV] # II, V
# not pick from II because original data doesn't have result from it
pick_nums = [350, 350, 350] # 6000
gen_data = random_generator(results, pick_nums)

gen_data.shape
# Out:
# (1050, 11)

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ### Preprocess data

# %%
# Preprocessing
from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# df = scaler.fit_transform(df)

# %% [markdown]
# ### Original data

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold

X = preprocess(df)
X, le_dict = labelEncoder_get(X)
y = labelList(df.shape[0], [678, 478, 745, 856, 535, 867, 689, 1415, 1418])

clf = DecisionTreeClassifier()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=42)

clf.fit(X_train, y_train)
y_predict = clf.predict(X_test)
print("Balanced accuracy score: {:.2f}".format(metrics.balanced_accuracy_score(y_test, y_predict)))
draw_confusionMatrix(y_test, y_predict)
# Out:
# Balanced accuracy score: 0.70
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       901
#            1       1.00      0.40      0.57         5
#
#     accuracy                           1.00       906
#    macro avg       1.00      0.70      0.78       906
# weighted avg       1.00      1.00      1.00       906

# %%
# X = preprocess(df)
# X, le_dict = labelEncoder_get(X)
# X_gen = preprocess(gen_data)
# X_gen = labelEncoder_trans(X_gen, le_dict)
# Counter(gen_data['LayerRTID']).items()
for i in range(len(gen_data)):
    gen_data['LayerRTID'] = np.nan
    gen_data['DestinationPort'] = np.nan

# %% [markdown]
# ### Original data with generated data
# Generated data should only be added into trianing set.

# %%
X_gen = preprocess(gen_data)
X_gen = labelEncoder_trans(X_gen, le_dict)
# add generated data to the original training set
X_train_new = pd.concat([X_train, X_gen], axis=0)

# generated data are all positive
for i in range(len(gen_data)):
    y_train.append(1)

clf.fit(X_train_new, y_train)
y_predict = clf.predict(X_test)
print("Balanced accuracy score: {:.2f}".format(metrics.balanced_accuracy_score(y_test, y_predict)))
draw_confusionMatrix(y_test, y_predict)
# Out:
# Channel
# EventID
# Message
# DestPort
# LayerRTID
# ParentProcessName
# NewProcessName
# ParentImage
# Image
# DestinationPort
# User
# Balanced accuracy score: 0.90
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       901
#            1       0.57      0.80      0.67         5
#
#     accuracy                           1.00       906
#    macro avg       0.79      0.90      0.83       906
# weighted avg       1.00      1.00      1.00       906

# %%
# draw the tree
from sklearn import tree

plt.figure(figsize=(30, 15))
tree.plot_tree(clf, feature_names=features, fontsize=10)
plt.title("Decision Tree - RemotePwshExecution")
plt.savefig(r'DecisionTree\RemotePwshExecution.png', dpi=100, transparent=True)

# %% [markdown]
# ## Save generated data

# %%
# # extract to JSON file
# dataset.reset_index(drop=True, inplace=True)
gen_data.to_json(os.getcwd() + r'\generated_datasets\empire_psremoting_stager_new1.json', orient='records')

# dataset = json.read_json(path_or_buf=os.getcwd()+ "\\generated_datasets"+ "\\empire_dllinjection_LoadLibrary_CreateRemoteThread_new.json")
# dataset.head()
